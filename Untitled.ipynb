# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /Users/alok/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /Users/alok/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/alok/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/alok/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/alok/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Step 1: Tokenization

from nltk.tokenize import word_tokenize

text = "I am learning NLP using Python."

words = word_tokenize(text)

print(words)
# Out:
# ['I', 'am', 'learning', 'NLP', 'using', 'Python', '.']

# %%
from nltk.tokenize import sent_tokenize

text = "Python is easy. NLP is interesting. AI is growing."

sentences = sent_tokenize(text)

print(sentences)
# Out:
# ['Python is easy.', 'NLP is interesting.', 'AI is growing.']

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Run only once
nltk.download('punkt')
nltk.download('stopwords')

text = "I am learning Python using NLTK"

words = word_tokenize(text)

stop_words = set(stopwords.words("english"))

filtered = []

for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

print("Original Words:", words)
print("Filtered Words:", filtered)
# Out:
# Original Words: ['I', 'am', 'learning', 'Python', 'using', 'NLTK']
# Filtered Words: ['learning', 'Python', 'using', 'NLTK']
# [nltk_data] Downloading package punkt to /Users/alok/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/alok/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

# Create Stemmer Object
stemmer = PorterStemmer()

# List of words
words = [
    "playing",
    "played",
    "plays",
    "player"
]

# Apply stemming
for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# playing -> play
# played -> play
# plays -> play
# player -> player

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Run only once
nltk.download('punkt')
nltk.download('stopwords')

text = "I am learning Python using NLTK"

words = word_tokenize(text)

stop_words = set(stopwords.words("english"))

filtered = []

for word in words:
    if word.lower() not in stop_words:
        filtered.append(word)

print("Original Words:", words)
print("Filtered Words:", filtered)
# Out:
# Original Words: ['I', 'am', 'learning', 'Python', 'using', 'NLTK']
# Filtered Words: ['learning', 'Python', 'using', 'NLTK']
# [nltk_data] Downloading package punkt to /Users/alok/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/alok/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

import joblib

# %%
data = pd.read_csv("SentimentData.csv")

X = data["text"]
y = data["sentiment"]

# %%
print(data)
# Out:
#                                text sentiment
# 0               I love this product  Positive
# 1                   This is amazing  Positive
# 2                 Excellent service  Positive
# 3      Very happy with the purchase  Positive
# 4                 Fantastic quality  Positive
# 5   Absolutely wonderful experience  Positive
# 6                Highly recommended  Positive
# 7                   Best phone ever  Positive
# 8            The food was delicious  Positive
# 9            Great customer support  Positive
# 10              I hate this product  Negative
# 11                Very disappointed  Negative
# 12            Worst experience ever  Negative
# 13         The service was terrible  Negative
# 14                     Poor quality  Negative
# 15               Completely useless  Negative
# 16                   Waste of money  Negative
# 17             Not satisfied at all  Negative
# 18              Very bad experience  Negative
# 19                    Awful product  Negative
# 20      The meeting starts at 10 AM   Neutral
# 21                  Today is Monday   Neutral
# 22        The package arrived today   Neutral
# 23             The weather is sunny   Neutral
# 24              The report is ready   Neutral
# 25         The train leaves at 5 PM   Neutral
# 26  I have completed the assignment   Neutral
# 27           This laptop costs $500   Neutral
# 28        The class begins tomorrow   Neutral
# 29          The store opens at 9 AM   Neutral

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Create TF-IDF Vectorizer
vect = TfidfVectorizer()

# Convert text into numerical features
X_vector = vect.fit_transform(X)

print(X_vector.shape)
# Out:
# (30, 70)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_vector,
    y,
    test_size=0.2,
    random_state=42
)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.fit(X_train, y_train)

joblib.dump(model, "model.pkl")
joblib.dump(vect, "vect.pkl")

print("Model Trained Successfully")
# Out:
# Model Trained Successfully
